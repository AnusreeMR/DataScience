# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (15,15))
x = np.array([1, 6])
y = np.array([3, 10])

plt.subplot(3, 3, 1)
plt.plot(x,y,'o')

font1 = {'color':'blue'}

plt.title("title 1")
plt.xlabel("y label",fontdict = font1)
plt.ylabel("x label",fontdict = font1)

x = np.array([4, 2, 4, 2,4])
y = np.array([2, 4, 2, 4,2])

plt.subplot(3, 3, 2)

plt.plot(x,linestyle = 'dashed',color='blue',linewidth = '2.5')
plt.plot(y,marker='*',color='orange',linewidth = '2.5')


y = np.array([1, 8, 3, 10])

plt.subplot(3, 3, 3)
plt.plot(y, marker = 'o', ms = 10, mec = 'k', mfc = 'y')

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])


plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.subplot(3, 3, 4)
plt.title("Title 2")
plt.plot(x,y)
plt.grid()

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 3, 6)
plt.plot(x,y)


x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 3, 7)
plt.plot(x,y)


x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 3, 8)
plt.plot(x,y)


x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 3, 9)
plt.plot(x,y)

plt.tight_layout()
plt.show()
